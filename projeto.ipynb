# %% [markdown]
# <a href="https://colab.research.google.com/github/JOHNPETER06/Data-mining/blob/main/projeto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('breast_cancer_enriched.csv')

# %%
df.head()
# Out:
#   patient_id  idade grupo_etario historico_familiar uso_hormonios  \
# 0   PAT_0001     63   Meia-idade                Não         Atual
# 1   PAT_0002     56   Meia-idade                Não         Nunca
# 2   PAT_0003     65        Idoso                Sim       Passado
# 3   PAT_0004     72        Idoso                Não         Nunca
# 4   PAT_0005     55   Meia-idade                Não       Passado
#
#   status_menopausa categoria_imc densidade_mamaria    metodo_deteccao  \
# 0    Pós-menopausa        Normal        Muito Alta  Mamografia rotina
# 1    Pós-menopausa        Normal        Muito Alta  Mamografia rotina
# 2    Pós-menopausa     Sobrepeso        Muito Alta          Autoexame
# 3    Pós-menopausa        Normal        Muito Alta       Exame médico
# 4    Pós-menopausa    Baixo peso        Muito Alta          Autoexame
#
#   regiao_geografica  ... texture3 perimeter3   area3  smoothness3  \
# 0               Sul  ...    17.33     184.60  2019.0       0.1622
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 44 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   patient_id               569 non-null    object
#  1   idade                    569 non-null    int64
#  2   grupo_etario             569 non-null    object
#  3   historico_familiar       569 non-null    object
#  4   uso_hormonios            569 non-null    object
#  5   status_menopausa         569 non-null    object
#  6   categoria_imc            569 non-null    object
#  7   densidade_mamaria        569 non-null    object
#  8   metodo_deteccao          569 non-null    object
#  9   regiao_geografica        569 non-null    object
#  10  nivel_socioeconomico     569 non-null    object
#  11  estagio_clinico          228 non-null    object
#  12  meses_desde_diagnostico  569 non-null    int64
#  13  radius1                  569 non-null    float64
# ...

# %%
df.describe()
# Out:
#             idade  meses_desde_diagnostico     radius1    texture1  \
# count  569.000000               569.000000  569.000000  569.000000
# mean    52.572935                62.657293   14.127292   19.289649
# std     13.550455                35.083858    3.524049    4.301036
# min     25.000000                 1.000000    6.981000    9.710000
# 25%     43.000000                31.000000   11.700000   16.170000
# 50%     53.000000                63.000000   13.370000   18.840000
# 75%     62.000000                93.000000   15.780000   21.800000
# max     85.000000               119.000000   28.110000   39.280000
#
#        perimeter1        area1  smoothness1  compactness1  concavity1  \
# count  569.000000   569.000000   569.000000    569.000000  569.000000
# mean    91.969033   654.889104     0.096360      0.104341    0.088799
# std     24.298981   351.914129     0.014064      0.052813    0.079720
# min     43.790000   143.500000     0.052630      0.019380    0.000000
# ...

# %%
df.isnull().sum()
# Out:
# patient_id                   0
# idade                        0
# grupo_etario                 0
# historico_familiar           0
# uso_hormonios                0
# status_menopausa             0
# categoria_imc                0
# densidade_mamaria            0
# metodo_deteccao              0
# regiao_geografica            0
# nivel_socioeconomico         0
# estagio_clinico            341
# meses_desde_diagnostico      0
# radius1                      0
# texture1                     0
# perimeter1                   0
# area1                        0
# smoothness1                  0
# compactness1                 0
# concavity1                   0
# concave_points1              0
# symmetry1                    0
# fractal_dimension1           0
# radius2                      0
# texture2                     0
# perimeter2                   0
# area2                        0
# smoothness2                  0
# compactness2                 0
# concavity2                   0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = df.corr(numeric_only=True) # Calcular correlação
sns.heatmap(corr, annot=False, cmap='coolwarm')
plt.title("Matriz de Correlação")
plt.show()

# %%
df.hist(figsize=(15,10), bins=20)
plt.tight_layout()
plt.show()

# %%
df_rounded = df.copy()

# %%
df_rounded = df_rounded.round(2)

# %%
df_rounded.head()
# Out:
#   patient_id idade grupo_etario historico_familiar uso_hormonios  \
# 0   PAT_0001    63   Meia-idade                Não         Atual
# 1   PAT_0002    56   Meia-idade                Não         Nunca
# 2   PAT_0003    65        Idoso                Sim       Passado
# 3   PAT_0004    72        Idoso                Não         Nunca
# 4   PAT_0005    55   Meia-idade                Não       Passado
#
#   status_menopausa categoria_imc densidade_mamaria    metodo_deteccao  \
# 0    Pós-menopausa        Normal        Muito Alta  Mamografia rotina
# 1    Pós-menopausa        Normal        Muito Alta  Mamografia rotina
# 2    Pós-menopausa     Sobrepeso        Muito Alta          Autoexame
# 3    Pós-menopausa        Normal        Muito Alta       Exame médico
# 4    Pós-menopausa    Baixo peso        Muito Alta          Autoexame
#
#   regiao_geografica  ... texture3 perimeter3   area3 smoothness3 compactness3  \
# ...

# %%
df = df_rounded

# %%
df.head()
# Out:
#   patient_id idade grupo_etario historico_familiar uso_hormonios  \
# 0   PAT_0001    63   Meia-idade                Não         Atual
# 1   PAT_0002    56   Meia-idade                Não         Nunca
# 2   PAT_0003    65        Idoso                Sim       Passado
# 3   PAT_0004    72        Idoso                Não         Nunca
# 4   PAT_0005    55   Meia-idade                Não       Passado
#
#   status_menopausa categoria_imc densidade_mamaria    metodo_deteccao  \
# 0    Pós-menopausa        Normal        Muito Alta  Mamografia rotina
# 1    Pós-menopausa        Normal        Muito Alta  Mamografia rotina
# 2    Pós-menopausa     Sobrepeso        Muito Alta          Autoexame
# 3    Pós-menopausa        Normal        Muito Alta       Exame médico
# 4    Pós-menopausa    Baixo peso        Muito Alta          Autoexame
#
#   regiao_geografica  ... texture3 perimeter3   area3 smoothness3 compactness3  \
# ...

# %%
df.to_csv('BCE_changed.csv')

# %%
df.to_excel('BCE_changed.xlsx')

# %%
df.to_csv('BCE_changed.csv')
